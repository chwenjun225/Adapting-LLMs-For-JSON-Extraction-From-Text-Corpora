# %% [markdown]
# ## llama-2-7b-json_extract-lora_adapter - Metrics for Various Tasks

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

tasks = ["arc_challenge", "arc_easy", "hellaswag", "openbookqa", "piqa"] 
data = { # TODO: Chỉ cần lấy `acc_norm` và sai số `stderr` của acc_norm xóa hết những số liệu còn lại 
    "Value": [0.4309, 0.6595, 0.7272, 0.3940, 0.7590], 
    "Stderr": [0.0145, 0.0097, 0.0044, 0.0219, 0.01]
}

x = np.arange(len(tasks))  # the label locations
width = 0.25  # the width of the bars
multiplier = 0

fig, ax = plt.subplots(layout='constrained')

df = pd.DataFrame(data)

for attribute, measurement in data.items():
    offset = width * multiplier
    rects = ax.bar(x + offset, measurement, width, label=attribute)
    ax.bar_label(rects, padding=3)
    multiplier += 1

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Values')
# ax.set_title('llama-31-8b-json_extract-lora_adapter - Metrics for Various Tasks')
ax.set_xticks(x + width, tasks, ha='right', rotation=45)
ax.legend(loc='upper left', ncols=3)
ax.set_ylim(0, 1)

plt.show()

# %% [markdown]
# ## llama-3-8b-json_extract-lora_adapter - Metrics for Various Tasks

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

tasks = ["arc_challenge", "arc_easy", "hellaswag", "openbookqa", "piqa"] 
data = { # TODO: Chỉ cần lấy `acc_norm` và sai số `stderr` của acc_norm xóa hết những số liệu còn lại 
    "Value": [0.4428, 0.6553, 0.7196, 0.4, 0.7508], 
    "Stderr": [0.0145, 0.0098, 0.0045, 0.0219, 0.0101]
}

x = np.arange(len(tasks))  # the label locations
width = 0.25  # the width of the bars
multiplier = 0

fig, ax = plt.subplots(layout='constrained')

df = pd.DataFrame(data)

for attribute, measurement in data.items():
    offset = width * multiplier
    rects = ax.bar(x + offset, measurement, width, label=attribute)
    ax.bar_label(rects, padding=3)
    multiplier += 1

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Values')
# ax.set_title('llama-31-8b-json_extract-lora_adapter - Metrics for Various Tasks')
ax.set_xticks(x + width, tasks, ha='right', rotation=45)
ax.legend(loc='upper left', ncols=3)
ax.set_ylim(0, 1)

plt.show()

# %% [markdown]
# ## llama-31-8b-json_extract-lora_adapter - Metrics for Various Tasks

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

tasks = ["arc_challenge", "arc_easy", "hellaswag", "openbookqa", "piqa"] 
data = { # TODO: Chỉ cần lấy `acc_norm` và sai số `stderr` của acc_norm xóa hết những số liệu còn lại 
    "Value": [0.4309, 0.6595, 0.7272, 0.394, 0.759], 
    "Stderr": [0.0145, 0.0097, 0.0044, 0.0219, 0.01]
}

x = np.arange(len(tasks))  # the label locations
width = 0.25  # the width of the bars
multiplier = 0

fig, ax = plt.subplots(layout='constrained')

df = pd.DataFrame(data)

for attribute, measurement in data.items():
    offset = width * multiplier
    rects = ax.bar(x + offset, measurement, width, label=attribute)
    ax.bar_label(rects, padding=3)
    multiplier += 1

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Values')
# ax.set_title('Llama-31-8b-json_extract-lora_adapter - Metrics for Various Tasks')
ax.set_xticks(x + width, tasks, ha='right', rotation=45)
ax.legend(loc='upper left', ncols=3)
ax.set_ylim(0, 1)

plt.show()
