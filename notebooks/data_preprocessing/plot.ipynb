# %% [markdown]
# # llama-31-8b-json_extract-lora_adapter

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

tasks = ["arc_challenge", "", "arc_easy", "", "hellaswag", "", "openbookqa", "", "piqa", ""]
data = { 
    "Value": [0.4087, 0.4309, 0.6999, 0.6595, 0.5502, 0.7272, 0.3040, 0.3940, 0.7481, 0.7590], 
    "Stderr": [0.0144, 0.0145, 0.0094, 0.0097, 0.0050, 0.0044, 0.0206, 0.0219, 0.0101, 0.0100]
}

x = np.arange(len(tasks))  # the label locations
width = 0.25  # the width of the bars
multiplier = 0

fig, ax = plt.subplots(layout='constrained')

df = pd.DataFrame(data)

for attribute, measurement in data.items():
    offset = width * multiplier
    rects = ax.bar(x + offset, measurement, width, label=attribute)
    ax.bar_label(rects, padding=3)
    multiplier += 1

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Values')
ax.set_title('llama-31-8b-json_extract-lora_adapter - Metrics for Various Tasks')
ax.set_xticks(x + width, tasks, rotation=45, ha='right')
ax.set_xticks(data['Value'])
ax.set_xticks(data["Stderr"])
ax.legend(loc='upper left', ncols=3)
ax.set_ylim(0, 1)

plt.show()

# %% [markdown]
# # llama3-8b-json_extract-lora_adapter - Metrics for Various Tasks

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

tasks = ["arc_challenge", "", "arc_easy", "", "hellaswag", "", "openbookqa", "", "piqa", ""]
data = { 
    "Value": [0.4172, 0.4428, 0.6869, 0.6553, 0.5468, 0.7196, 0.2900, 0.4000, 0.7454, 0.7508], 
    "Stderr": [0.0144, 0.0145, 0.0095, 0.0098, 0.0050, 0.0045, 0.0203, 0.0219, 0.0102, 0.0101]
}

x = np.arange(len(tasks))  # the label locations
width = 0.25  # the width of the bars
multiplier = 0

fig, ax = plt.subplots(layout='constrained')

df = pd.DataFrame(data)

for attribute, measurement in data.items():
    offset = width * multiplier
    rects = ax.bar(x + offset, measurement, width, label=attribute)
    ax.bar_label(rects, padding=3)
    multiplier += 1

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Values')
ax.set_title('llama-3-8b-json_extract-lora_adapter - Metrics for Various Tasks')
ax.set_xticks(x + width, tasks, rotation=45, ha='right')
ax.set_xticks(data['Value'])
ax.set_xticks(data["Stderr"])
ax.legend(loc='upper left', ncols=3)
ax.set_ylim(0, 1)

plt.show()

# %% [markdown]
# # llama2-7b-json_extract-lora_adapter - Metrics for Various Tasks

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

tasks = ["arc_challenge", "", "arc_easy", "", "hellaswag", "", "openbookqa", "", "piqa", ""]
data = { 
    "Value": [0.4258, 0.4556, 0.7445, 0.7235, 0.5674, 0.7531, 0.3260, 0.4420, 0.7818, 0.7802], 
    "Stderr": [0.0144, 0.0146, 0.0089, 0.0092, 0.0049, 0.0043, 0.0210, 0.0222, 0.0096, 0.0097]
}

x = np.arange(len(tasks))  # the label locations
width = 0.25  # the width of the bars
multiplier = 0

fig, ax = plt.subplots(layout='constrained')

df = pd.DataFrame(data)

for attribute, measurement in data.items():
    offset = width * multiplier
    rects = ax.bar(x + offset, measurement, width, label=attribute)
    ax.bar_label(rects, padding=3)
    multiplier += 1

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Values')
ax.set_title('llama-2-7b-json_extract-lora_adapter - Metrics for Various Tasks')
ax.set_xticks(x + width, tasks, rotation=45, ha='right')
ax.set_xticks(data['Value'])
ax.set_xticks(data["Stderr"])
ax.legend(loc='upper left', ncols=3)
ax.set_ylim(0, 1)

plt.show()
